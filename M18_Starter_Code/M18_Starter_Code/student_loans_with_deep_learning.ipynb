# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %%
# Review the data types associated with the columns
loans_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# 1    855
# 0    744
# Name: credit_ranking, dtype: int64

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column
y = loans_df["credit_ranking"].values

# Display a sample of y
y[:5]
# Out:
# array([0, 0, 0, 1, 0])

# %%
# Define features set X by selecting all columns but credit_ranking
X = loans_df.drop('credit_ranking', axis=1)

# Review the features DataFrame
X.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the scaler to the features training dataset
X_scaler = scaler.fit(X_train)

# Fit the scaler to the features training dataset - this is twice maybe this is really transform or maybe it is y?  will check!
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Define the the number of inputs (features) to the model
number_input_features = X_train.shape[1]


# Review the number of features
number_input_features
# Out:
# 11

# %%
# Define the number of hidden nodes for the first hidden layer
# according to class we should start smaller and alter as needed, there are issues with overfitting when adding to many nodes
# also in the answers it says 6 for first and 3 for second layer so there is that too
hidden_nodes_layer1 = 6

# Define the number of hidden nodes for the second hidden layer
hidden_nodes_layer2 = 3

# Define the number of neurons in the output layer
# Note to self: there are only two options give loan or don't so I am thinking 2 output layer
output_layer = 2

# %%
# Create the Sequential model instance
nn = tf.keras.models.Sequential()

# Add the first hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Add the second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Add the output layer to the model specifying the number of output neurons and activation function
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Display the Sequential model summary
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 6)                 72
#
#  dense_4 (Dense)             (None, 3)                 21
#
#  dense_5 (Dense)             (None, 1)                 4
#
# ...
# Total params: 97 (388.00 Byte)
# Trainable params: 97 (388.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data
fit_model = nn.fit(X_train_scaled,y_train,epochs=50)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 1s 2ms/step - loss: 0.6828 - accuracy: 0.5763
# Epoch 2/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6733 - accuracy: 0.5988
# Epoch 3/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6613 - accuracy: 0.6330
# Epoch 4/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6470 - accuracy: 0.6597
# Epoch 5/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6308 - accuracy: 0.6764
# Epoch 6/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6142 - accuracy: 0.6889
# Epoch 7/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5975 - accuracy: 0.6956
# Epoch 8/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5823 - accuracy: 0.7089
# Epoch 9/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5692 - accuracy: 0.7131
# Epoch 10/50
# ...

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)

# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 13/13 - 0s - loss: 0.5240 - accuracy: 0.7225 - 192ms/epoch - 15ms/step
# Loss: 0.5240213871002197, Accuracy: 0.7225000262260437

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.

# %%
# Set the model's file path
file_path = Path("student_loans.keras")

# Export your model to a keras file
nn.save(file_path)

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path
file_path = Path("student_loans.keras")

# Load the model to a new object
nn_imported = tf.keras.models.load_model(file_path)

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data
predictions = nn_imported.predict(X_test_scaled,verbose=2)

# Display a sample of the predictions
predictions[:5]
# Out:
# 13/13 - 0s - 37ms/epoch - 3ms/step
# array([[0.67857635],
#        [0.257427  ],
#        [0.9243679 ],
#        [0.70794857],
#        [0.98324245]], dtype=float32)

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
predictions_df = pd.DataFrame(columns=["predictions"], data=predictions)
predictions_df["predictions"] = round(predictions_df["predictions"],0)
predictions_df
# Out:
#      predictions
# 0            1.0
# 1            0.0
# 2            1.0
# 3            1.0
# 4            1.0
# ..           ...
# 395          1.0
# 396          0.0
# 397          1.0
# 398          0.0
# 399          1.0
#
# [400 rows x 1 columns]

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
# Print the classification report with the y test data and predictions
print(classification_report(y_test, predictions_df["predictions"].values))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.76      0.72       188
#            1       0.76      0.69      0.73       212
#
#     accuracy                           0.72       400
#    macro avg       0.72      0.72      0.72       400
# weighted avg       0.73      0.72      0.72       400

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# Briefly answer the following questions in the space provided:
#
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.

# %% [markdown]
# **1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.**
#
# In oder to build a recommendation system to recommend student loand options we would need to include the following data:
#
# *   co-signers: information about anyone that would be able to co-sign with the student loan of the student e.g., co-signer's income, employement status, age
# *   demographic information such as age, location and education level
# *   credit histry of the student
#
# This data would be appropriate if it is numeric or catigorical because a recommendation system needs to have non-textual data to build the model.  Also, by adding in co-signer information that will limit the liability of company (if a payment is missed or defered there is another person to collect payment).  By adding in demographic information to the model we can predict financial solvency for the loan (individuals with greater education levels typically make more money than less educated, older individual are typically more finacially secure and location because of deposible cash due to living expenses).
#
# **2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.**
#
# I would suggest that we use a combination of context and content-based filtering because this will better take into account the circumstances of the borrower who is applying for the loan and if they like the loan options that we are offering to the student.  For instance, payment and credit history will tell you what the student has done in the past while the student's income will tell you if they will be able to afford a payment - context-based arguments. While content-based would provide loan options for the student including items like interest rate, loan amount or the duration of the loan.
#
#
# **3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.**
#
# Securing the data (1) and appending it to the student file(2) would be  challeges.
#
# There are multiple steps in being able to secure the data and this might include data privacy and general security. If the vast majority of the individuals are younger then thier finacial history might be more difficult to secure due to privacy concerns. Addiitonally, general security surrounding financial data is intense as well, there are multiple levels of security to get to individua level data that this company might not be able to pass.
#
# Which brings us to... there is data out there but typically these data do not have a one to one link to each individual's financial history.  This would mean that we would have to deploy imputation techniques or dataframes that do not have all data that would be needed to make a great recommender system - both would degrade the model slightly.
